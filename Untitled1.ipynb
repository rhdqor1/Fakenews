# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\허\Social-Network-Analysis\WELFake_Dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1           1                                                NaN
# 2           2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3           3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4           4  SATAN 2: Russia unvelis an image of its terrif...
#
#                                                 text  label
# 0  No comment is expected from Barack Obama Membe...      1
# 1     Did they post their votes for Hillary already?      1
# 2   Now, most of the demonstrators gathered last ...      1
# 3  A dozen politically active pastors came here f...      0
# 4  The RS-28 Sarmat missile, dubbed Satan 2, will...      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71537 entries, 0 to 72133
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        71537 non-null  object
#  1   text         71537 non-null  object
#  2   label        71537 non-null  int64
#  3   text_length  71537 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 2.7+ MB

# %%
df.shape
# Out:
# (71537, 4)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'text', 'label'], dtype='object')

# %%
df.describe()
# Out:
#               label
# count  71537.000000
# mean       0.510351
# std        0.499896
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# title         558
# text           39
# label           0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (71537, 4)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# title         0
# text          0
# label         0
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# label
# 1    36509
# 0    35028
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt


df['label'].value_counts().sort_index(ascending=False).plot(kind='barh')

plt.title("Fake vs Real News")
plt.xlabel("Count")
plt.ylabel("Label")
plt.show()

# %%
#제목길이분석
df['title_length'] = df['title'].apply(len)

df['title_length'].describe()
# Out:
# count    71537.000000
# mean        77.130240
# std         25.028377
# min          1.000000
# 25%         62.000000
# 50%         73.000000
# 75%         89.000000
# max        456.000000
# Name: title_length, dtype: float64

# %%
#본문길이분석
df['text_length'] = df['text'].apply(len)

df['text_length'].describe()
# Out:
# count     71537.000000
# mean       3292.722116
# std        3738.194002
# min           1.000000
# 25%        1410.000000
# 50%        2440.000000
# 75%        4077.000000
# max      142961.000000
# Name: text_length, dtype: float64

# %%
#히스토그램
plt.hist(df['text_length'], bins=50)
plt.title("News Text Length Distribution")
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
df = df.drop(columns=['Unnamed: 0'])
df = df.dropna()

print(df.shape)

print(df['label'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df = df.drop(columns=['Unnamed: 0'])
#       2 df = df.dropna()
#       4 print(df.shape)
#
# File C:\Python\anaconda\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File C:\Python\anaconda\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File C:\Python\anaconda\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File C:\Python\anaconda\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

X = df['text']
y = df['label']

vectorizer = TfidfVectorizer(
    max_features=5000,
    stop_words='english'
)

X_tfidf = vectorizer.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf,
    y,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(
    max_iter=1000
)

model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test, y_pred)

print("정확도 :", acc)
# Out:
# 정확도 : 0.9373776908023483

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[6565  516]
#  [ 380 6847]]

# %%
from sklearn.metrics import classification_report

print(
    classification_report(
        y_test,
        y_pred
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      7081
#            1       0.93      0.95      0.94      7227
#
#     accuracy                           0.94     14308
#    macro avg       0.94      0.94      0.94     14308
# weighted avg       0.94      0.94      0.94     14308

# %%
import matplotlib.pyplot as plt

df['label'].value_counts().plot(kind='bar')

plt.title("진짜 vs 가짜뉴스")
plt.xlabel("Label")
plt.ylabel("Count")
plt.show()

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=['Fake','Real']
)

fig, ax = plt.subplots(figsize=(6,6))
disp.plot(ax=ax)

plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test, y_pred)

plt.figure(figsize=(5,4))
plt.bar(['Accuracy'], [acc])

plt.ylim(0,1)

plt.title("정확도")
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

feature_names = vectorizer.get_feature_names_out()

scores = X_tfidf.sum(axis=0).A1

word_df = pd.DataFrame({
    'word': feature_names,
    'score': scores
})

top20 = word_df.sort_values(
    by='score',
    ascending=False
).head(20)
plt.figure(figsize=(10,6))

plt.barh(
    top20['word'],
    top20['score']
)

plt.title("중요 단어 Top 20")
plt.show()

# %%
counts = df['label'].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    counts,
    labels=['Real','Fake'],
    autopct='%1.1f%%'
)

plt.title("News Distribution")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

y_score = model.predict_proba(X_test)[:,1]

fpr, tpr, _ = roc_curve(y_test, y_score)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))
plt.plot(fpr, tpr,
         label=f'AUC={roc_auc:.3f}')

plt.plot([0,1],[0,1],'--')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.title('ROC Curve')
plt.legend()

plt.show()

# %%
import plotly.express as px

fig = px.histogram(
    df,
    x="text_length",
    color="label",
    title="News Length Distribution"
)

fig.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["text"].astype(str))

wc = WordCloud(
    width=1200,
    height=600,
    background_color="white"
).generate(text)

plt.figure(figsize=(15,7))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
df['text_length'] = df['text'].astype(str).apply(len)

# %%
df.columns
# Out:
# Index(['title', 'text', 'label', 'text_length'], dtype='object')

# %%
#가짜뉴스 vs 진짜뉴스분포
import matplotlib.pyplot as plt

counts = df['label'].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    counts,
    labels=['Real News','Fake News'],
    autopct='%1.1f%%'
)

plt.title("Distribution of News Labels")

plt.show()

# %%
#뉴스 길이 분포
plt.figure(figsize=(10,6))

plt.hist(
    df['text_length'],
    bins=50
)

plt.title("News Text Length Distribution")
plt.xlabel("Length")
plt.ylabel("Count")

plt.show()

# %%
#진짜 가짜 길이 비교
fake_len = df[df['label']==0]['text_length']
real_len = df[df['label']==1]['text_length']

plt.figure(figsize=(10,6))

plt.boxplot(
    [fake_len, real_len],
    tick_labels=['Fake News','Real News']
)

plt.title("News Length Comparison")

plt.show()

# %%
#학습
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test,y_pred)

print(acc)
# Out:
# 0.9373776908023483

# %%
plt.figure(figsize=(5,5))

plt.bar(
    ['Accuracy'],
    [acc*100]
)

plt.ylim(0,100)

plt.ylabel('Percentage (%)')
plt.title('Model Accuracy')

for i,v in enumerate([acc*100]):
    plt.text(i,v+1,f'{v:.2f}%')

plt.show()

# %%
#모델 가짜뉴스와 진짜뉴스 구분
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

y_score = model.predict_proba(X_test)[:,1]

fpr,tpr,_ = roc_curve(y_test,y_score)

roc_auc = auc(fpr,tpr)

plt.figure(figsize=(7,7))

plt.plot(
    fpr,
    tpr,
    label=f"AUC={roc_auc:.3f}"
)

plt.plot(
    [0,1],
    [0,1],
    '--'
)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.show()

# %%
#참 거짓 확률
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(7,6))
plt.imshow(cm, cmap='Blues')

plt.colorbar()

plt.xticks([0,1], ['Fake','Real'])
plt.yticks([0,1], ['Fake','Real'])

plt.xlabel("Predicted")
plt.ylabel("Actual")

labels = [
    ["Success\n"+str(cm[0,0]),
     "Wrong\n"+str(cm[0,1])],

    ["Wrong\n"+str(cm[1,0]),
     "Success\n"+str(cm[1,1])]
]

for i in range(2):
    for j in range(2):
        plt.text(
            j,
            i,
            labels[i][j],
            ha='center',
            va='center',
            fontsize=11,
            color='black'
        )

plt.title("Confusion Matrix")
plt.show()

# %%
#모델 비교
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

nb = MultinomialNB()

nb.fit(X_train, y_train)

pred_nb = nb.predict(X_test)

acc_nb = accuracy_score(y_test, pred_nb)

print("Logistic Regression :", acc)
print("Naive Bayes :", acc_nb)
# Out:
# Logistic Regression : 0.9373776908023483
# Naive Bayes : 0.8452613922281241

# %%
#모델 비교
import matplotlib.pyplot as plt

models = ['Logistic Regression', 'Naive Bayes']
scores = [acc, acc_nb]

plt.figure(figsize=(8,5))
plt.bar(models, scores)

plt.ylabel("Accuracy")
plt.ylim(0.8,1)

for i,v in enumerate(scores):
    plt.text(i,v+0.005,f"{v:.4f}")

plt.title("Model Performance Comparison")

plt.show()

# %%
#진짜 뉴스 판단 단어
feature_names = vectorizer.get_feature_names_out()

coef = model.coef_[0]

top_real_idx = coef.argsort()[-20:]

real_words = feature_names[top_real_idx]
real_scores = coef[top_real_idx]

# %%
#진짜 뉴스 판단 단어
plt.figure(figsize=(10,6))

plt.barh(real_words, real_scores)

plt.title("Top 20 Words Predicting Real News")

plt.xlabel("Importance")

plt.show()

# %%
#가짜 뉴스 판단 단어
top_fake_idx = coef.argsort()[:20]

fake_words = feature_names[top_fake_idx]
fake_scores = coef[top_fake_idx]

# %%
#가짜 뉴스 판단 그래프
plt.figure(figsize=(10,6))

plt.barh(fake_words, fake_scores)

plt.title("Top 20 Words Predicting Fake News")

plt.xlabel("Importance")

plt.show()
